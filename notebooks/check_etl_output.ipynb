# %%
import pandas as pd
import numpy as np
import os
import re
# Out:
# 22/10/02 18:23:31 WARN Utils: Your hostname, Polaris resolves to a loopback address: 127.0.1.1; using 172.26.153.20 instead (on interface eth0)
# 22/10/02 18:23:31 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 22/10/02 18:23:33 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Welcome to
#       ____              __
#      / __/__  ___ _____/ /__
#     _\ \/ _ \/ _ `/ __/  '_/
#    /__ / .__/\_,_/_/ /_/\_\   version 3.3.0
#       /_/
#
# Using Python version 3.8.10 (default, Jun 22 2022 20:18:18)
# Spark context Web UI available at http://172.26.153.20:4040
# Spark context available as 'sc' (master = local[*], app id = local-1664695413881).
# SparkSession available as 'spark'.
# ...

# %%
curated_df = pd.read_parquet('../data/curated/final_merchant_statistics')
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# /mnt/c/Users/Xavier Travers/Desktop/Uni/ADS/generic-buy-now-pay-later-project-group-19/notebooks/check_etl_output.ipynb Cell 2 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/mnt/c/Users/Xavier%20Travers/Desktop/Uni/ADS/generic-buy-now-pay-later-project-group-19/notebooks/check_etl_output.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> curated_df = spark.read.parquet('../data/curated/curated')
#
# File ~/.local/lib/python3.8/site-packages/pyspark/sql/readwriter.py:364, in DataFrameReader.parquet(self, *paths, **options)
#     353 int96RebaseMode = options.get("int96RebaseMode", None)
#     354 self._set_opts(
#     355     mergeSchema=mergeSchema,
#     356     pathGlobFilter=pathGlobFilter,
#    (...)
#     361     int96RebaseMode=int96RebaseMode,
#     362 )
# ...

# %%
curated_df.sort_values('no_orders')
# Out:
#       merchant_abn                              name  \
# 2738   55092047467         Lectus Justo Incorporated
# 715    83199298021    Ligula Elit Pretium Foundation
# 2625   10739268011      Libero Proin Mi Incorporated
# 3205   49514806178           Hendrerit Id Ante Corp.
# 3459   64648788229                 Nisl Maecenas LLC
# ...            ...                               ...
# 3762   93267734067                  Curae Foundation
# 3791   14616123867  Fringilla Porttitor Vulputate PC
# 3878   42461534060                          Elit LLP
# 3904   52524795452         Cras Convallis Associates
# 4005   93915598279        Molestie Pharetra Nibh LLP
#
#                                                    tags  \
# 2738  [(jewelry, Watch, clock, and silverware shops)...
# 715   [[antique shops - sales, repairs, and restorat...
# 2625  [[art dealers and galleries], [a], [take rate:...
# 3205  ([jewelry, watch, clock, and silverware shops]...
# ...
